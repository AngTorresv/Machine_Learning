# %% [markdown]
# # Practica para usar graficos interactivos

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('population_total-graficos interactivos.csv')
df
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
import cufflinks as cf
from IPython.display import display,HTML 
cf.set_config_file(sharing='public',theme='space',offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.getThemes()
# Out:
# ['ggplot', 'pearl', 'solar', 'space', 'white', 'polar', 'henanigans']

# %%
df.isnull().sum()
# Out:
# country       0
# year          7
# population    7
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# country       0
# year          0
# population    0
# dtype: int64

# %%
df = df.pivot(index='year', columns= 'country',values='population')
df
# Out:
# country  Afghanistan    Albania     Algeria  American Samoa  Andorra  \
# year
# 1955.0     8270991.0  1419994.0   9774283.0         19754.0   9232.0
# 1960.0     8996973.0  1636090.0  11057863.0         20123.0  13411.0
# 1965.0     9956320.0  1896171.0  12550885.0         23672.0  18549.0
# 1970.0    11173642.0  2150707.0  14464985.0         27363.0  24276.0
# 1975.0    12689160.0  2411732.0  16607707.0         30052.0  30705.0
# 1980.0    13356511.0  2682690.0  19221665.0         32646.0  36067.0
# 1985.0    11938208.0  2969672.0  22431502.0         39519.0  44600.0
# 1990.0    12412308.0  3286073.0  25758869.0         47347.0  54509.0
# 1995.0    18110657.0  3112936.0  28757785.0         53161.0  63850.0
# 2000.0    20779953.0  3129243.0  31042235.0         57821.0  65390.0
# 2005.0    25654277.0  3086810.0  33149724.0         59562.0  78867.0
# 2010.0    29185507.0  2948023.0  35977455.0         56079.0  84449.0
# ...

# %%
df = df[['United States','India','China','Indonesia','Brazil']]
df
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 1955.0     171685336.0  4.098806e+08  6.122416e+08   77273425.0   62533919.0
# 1960.0     186720571.0  4.505477e+08  6.604081e+08   87751068.0   72179226.0
# 1965.0     199733676.0  4.991233e+08  7.242190e+08  100267062.0   83373530.0
# 1970.0     209513341.0  5.551898e+08  8.276014e+08  114793178.0   95113265.0
# 1975.0     219081251.0  6.231029e+08  9.262409e+08  130680727.0  107216205.0
# 1980.0     229476354.0  6.989528e+08  1.000089e+09  147447836.0  120694009.0
# 1985.0     240499825.0  7.843600e+08  1.075589e+09  164982451.0  135274080.0
# 1990.0     252120309.0  8.732778e+08  1.176884e+09  181413402.0  149003223.0
# 1995.0     265163745.0  9.639226e+08  1.240921e+09  196934260.0  162019896.0
# 2000.0     281710909.0  1.056576e+09  1.290551e+09  211513823.0  174790340.0
# 2005.0     294993511.0  1.147610e+09  1.330776e+09  226289470.0  186127103.0
# ...

# %% [markdown]
# # LinePlot

# %%
df.iplot(kind='line',xTitle='Year',yTitle='population',title='year vs population')
# Out:
# <div>                            <div id="af6967e3-2bc2-4ec6-a8be-79bd859fde62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Barplot

# %%
df2020 = df[df.index.isin([2020])]
df2020 = df2020.T

# %%
df2020.iplot(kind='bar',xTitle='conuntries',yTitle='population',title=' population 2020', color='white' )
# Out:
# <div>                            <div id="d8144adc-7244-4e0c-80d8-90d595e63915" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
dfdecada = df[df.index.isin([1980,1990,2000,2010,2020])]
dfdecada.iplot(kind='bar',xTitle='conuntries',yTitle='population',title=' population 2020' )
# Out:
# <div>                            <div id="78345d18-e6e6-4389-80d7-438252885dde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Boxplot

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="4bc39884-6515-486f-8399-4cd6b06c07b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Histograma

# %%
df[['United States','China']].iplot(kind='hist',title='population United States')
# Out:
# <div>                            <div id="82f6ecfe-3cc7-4dba-a1aa-79039c5fad5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # piechart

# %%
df2020 = df2020.reset_index()
df2020 = df2020.rename(columns={2020:'2020' })
df2020
# Out:
# year        country          2020
# 0     United States  3.310027e+08
# 1             India  1.380004e+09
# 2             China  1.439324e+09
# 3         Indonesia  2.735236e+08
# 4            Brazil  2.125594e+08

# %%
df2020.iplot(kind ='pie',labels='country',values='2020',title= 'population comparation')
# Out:
# <div>                            <div id="c7214a71-7f67-400c-ba58-8c1a783a0bb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # scatter plot

# %%
df.iplot(kind='scatter',mode='markers',xTitle='Year',yTitle='population',title= 'Year vs population')
# Out:
# <div>                            <div id="04a532db-79a5-4e26-8a8f-004347f80f14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
